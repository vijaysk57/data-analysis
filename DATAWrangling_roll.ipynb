# %% [markdown]
# news api

# %%
import requests

url = "https://reuters-business-and-financial-news.p.rapidapi.com/market-rics/list-rics-by-asset-and-category/1/1"

headers = {
	"x-rapidapi-key": "0366092ba6mshe87fbeb9194cd76p1c4ab9jsnc059efff2478",
	"x-rapidapi-host": "reuters-business-and-financial-news.p.rapidapi.com"
}

response = requests.get(url, headers=headers)
result = response.json()
print(response.json())
# Out:
# {'statusCode': 200, 'marketAsset': 'Commodities', 'marketCategory': 'Agriculture', 'assetData': [{'typeName': 'Commodity Future', 'rics': ['Cc1', 'Wc1', 'Sc1', 'FCPOc1', 'NSBc1', 'NRSc1', 'SBc1', 'KCc1', 'CCc1', 'CTc1', 'LBc1', 'OJc1', 'JRUc1', 'LBc1', 'JRUc1', 'JRUc1', 'LBc1', 'Cc1', 'Wc1', 'FCPOc1', 'Sc1', 'FCPOc1', 'NSBc1', 'NRSc1', 'SBc1', 'KCc1', 'CCc1', 'CTc1', 'LBc1', 'OJc1', 'JRUc1', 'LBc1']}]}

# %%
import pandas as pd
newsdata = pd.DataFrame(result)
newsdata.head()
# Out:
#    statusCode  marketAsset marketCategory  \
# 0         200  Commodities    Agriculture
#
#                                            assetData
# 0  {'typeName': 'Commodity Future', 'rics': ['Cc1...

# %%
newsdata.to_csv(r"C:\my files\rapido.csv")

# %%
import requests
page = requests.get("https://randomfox.ca/floof")

# %%
print(page)
# Out:
# <Response [200]>

# %%
result = page.json()
print(result)
# Out:
# {'image': 'https://randomfox.ca/images/104.jpg', 'link': 'https://randomfox.ca/?i=104'}

# %%
result["image"]
# Out:
# 'https://randomfox.ca/images/104.jpg'

# %% [markdown]
# weather api

# %%
import requests

# %%
page = requests.get('http://api.weatherapi.com/v1/current.json?key=5336e6c1f50044b4bf285935252003&q=Tumkur')

# %%
print(page)
# Out:
# <Response [200]>

# %%
result = page.json()
print(result)
# Out:
# {'location': {'name': 'Tumkur', 'region': 'Karnataka', 'country': 'India', 'lat': 13.3422, 'lon': 77.1017, 'tz_id': 'Asia/Kolkata', 'localtime_epoch': 1742464785, 'localtime': '2025-03-20 15:29'}, 'current': {'last_updated_epoch': 1742463900, 'last_updated': '2025-03-20 15:15', 'temp_c': 34.7, 'temp_f': 94.4, 'is_day': 1, 'condition': {'text': 'Sunny', 'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png', 'code': 1000}, 'wind_mph': 8.9, 'wind_kph': 14.4, 'wind_degree': 115, 'wind_dir': 'ESE', 'pressure_mb': 1010.0, 'pressure_in': 29.82, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 16, 'cloud': 4, 'feelslike_c': 32.8, 'feelslike_f': 91.0, 'windchill_c': 34.7, 'windchill_f': 94.4, 'heatindex_c': 32.8, 'heatindex_f': 91.0, 'dewpoint_c': 5.5, 'dewpoint_f': 41.9, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 5.3, 'gust_mph': 10.3, 'gust_kph': 16.6}}

# %%
import requests

# %%
page = requests.get('https://api.coincap.io/v2/assets')

# %%
print(page)
# Out:
# <Response [200]>

# %%
res = page.json()
print(res)
# Out:
# {'data': [{'id': 'bitcoin', 'rank': '1', 'symbol': 'BTC', 'name': 'Bitcoin', 'supply': '19839400.0000000000000000', 'maxSupply': '21000000.0000000000000000', 'marketCapUsd': '1703624465583.7318028789872200', 'volumeUsd24Hr': '10141491358.5569542210115864', 'priceUsd': '85870.7655263632873413', 'changePercent24Hr': '2.8551634101947795', 'vwap24Hr': '85201.0651284456121972', 'explorer': 'https://blockchain.info/'}, {'id': 'ethereum', 'rank': '2', 'symbol': 'ETH', 'name': 'Ethereum', 'supply': '120629195.4269564900000000', 'maxSupply': None, 'marketCapUsd': '241878442707.8441621012277324', 'volumeUsd24Hr': '6621521654.7663726314683607', 'priceUsd': '2005.1401474720656370', 'changePercent24Hr': '3.2718447770705386', 'vwap24Hr': '2023.0357853491439004', 'explorer': 'https://etherscan.io/'}, {'id': 'xrp', 'rank': '3', 'symbol': 'XRP', 'name': 'XRP', 'supply': '58108919817.0000000000000000', 'maxSupply': '100000000000.0000000000000000', 'marketCapUsd': '145776030025.7492526890418213', 'volu
# ...

# %%
data = res["data"]

# %%
import pandas as pd
df1 = pd.DataFrame(data)
df1.head()
# Out:
#              id rank symbol      name                         supply  \
# 0       bitcoin    1    BTC   Bitcoin      19839400.0000000000000000
# 1      ethereum    2    ETH  Ethereum     120629195.4269564900000000
# 2           xrp    3    XRP       XRP   58108919817.0000000000000000
# 3        tether    4   USDT    Tether  143653509034.0653000000000000
# 4  binance-coin    5    BNB       BNB     144006830.0000000000000000
#
#                        maxSupply                    marketCapUsd  \
# 0      21000000.0000000000000000  1703624465583.7318028789872200
# 1                           None   241878442707.8441621012277324
# 2  100000000000.0000000000000000   145776030025.7492526890418213
# 3                           None   143725557538.7823927347936911
# 4     144006830.0000000000000000    91526615556.1936422713777770
#
#                   volumeUsd24Hr                priceUsd   changePercent24Hr  \
# 0  10141491358.5569542210115864  85870.7655263632873413  2.8551634101947795
# ...

# %%
df1.to_csv("C:\my files\coindata.csv")

# %%
df1.tail()
# Out:
#                id rank symbol           name                       supply  \
# 95         helium   96    HNT         Helium   179761124.7451054500000000
# 96           kava   97   KAVA           Kava  1082853482.0000000000000000
# 97   pyth-network   98   PYTH   Pyth Network  3624987919.8500000000000000
# 98        raydium   99    RAY        Raydium   290847970.9593340000000000
# 99  axie-infinity  100    AXS  Axie Infinity   159646968.7628623500000000
#
#                      maxSupply                marketCapUsd  \
# 95  223000000.0000000000000000  581167981.9720361915761794
# 96                        None  562264313.9949838259859914
# 97                        None  553357764.1984658130640844
# 98  555000000.0000000000000000  551628326.9655487873303833
# 99                        None  548791772.6445365150604969
#
#                 volumeUsd24Hr            priceUsd   changePercent24Hr  \
# 95    718506.3706905863084963  3.2330014779119270  5.0881589953613069
# ...

# %%
df1.isnull().sum()
# Out:
# id                    0
# rank                  0
# symbol                0
# name                  0
# supply                0
# maxSupply            56
# marketCapUsd          0
# volumeUsd24Hr         0
# priceUsd              0
# changePercent24Hr     0
# vwap24Hr              2
# explorer             11
# dtype: int64

# %%
df1.dropna(inplace = True)
df1.isnull().sum()
# Out:
# id                   0
# rank                 0
# symbol               0
# name                 0
# supply               0
# maxSupply            0
# marketCapUsd         0
# volumeUsd24Hr        0
# priceUsd             0
# changePercent24Hr    0
# vwap24Hr             0
# explorer             0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40 entries, 0 to 98
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 40 non-null     object
#  1   rank               40 non-null     object
#  2   symbol             40 non-null     object
#  3   name               40 non-null     object
#  4   supply             40 non-null     object
#  5   maxSupply          40 non-null     object
#  6   marketCapUsd       40 non-null     object
#  7   volumeUsd24Hr      40 non-null     object
#  8   priceUsd           40 non-null     object
#  9   changePercent24Hr  40 non-null     object
#  10  vwap24Hr           40 non-null     object
#  11  explorer           40 non-null     object
# dtypes: object(12)
# memory usage: 4.1+ KB

# %%
df1.describe(include='all')
# Out:
#              id rank symbol     name                     supply  \
# count        40   40     40       40                         40
# unique       40   40     40       40                         40
# top     bitcoin    1    BTC  Bitcoin  19839400.0000000000000000
# freq          1    1      1        1                          1
#
#                         maxSupply                    marketCapUsd  \
# count                          40                              40
# unique                         33                              40
# top     21000000.0000000000000000  1703624465583.7318028789872200
# freq                            3                               1
#
#                        volumeUsd24Hr                priceUsd  \
# count                             40                      40
# unique                            40                      40
# top     10141491358.5569542210115864  85870.7655263632873413
# freq                               1                       1
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize = (6,5))
sns.histplot(df1["marketCapUsd"],kde = True, bins =10)
plt.title("coindata")
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# 1) create a scatter plot between name and price

# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
x=(df1["name"])
y=(df1["priceUsd"])
plt.scatter(x,y,color='blue',marker='o',label='data points')
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.xticks(rotation = 45)
plt.yticks(rotation = 35)
plt.legend()
plt.show()

# %% [markdown]
# filter the data where the price is less than 2 and plot a scatter plot

# %%
df1["priceUsd"]=df1["priceUsd"].astype(float)
filt =df1[df1["priceUsd"]<2]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (20,5))
plt.scatter(df1["symbol"],df1["priceUsd"],label = "price",color = "green")
plt.show()
